# %%
import pandas as pd 
df = pd.read_csv('PRPL-Facebook-Government-Report-2020_H1.csv')
df
# Out:
#                Country Preservation Requests Preservation Accounts Preserved  \
# 0          Afghanistan                     0                               0
# 1        Aland Islands                     0                               0
# 2              Albania                     9                               9
# 3              Algeria                     1                               1
# 4       American Samoa                     0                               0
# ..                 ...                   ...                             ...
# 246  Wallis and Futuna                     0                               0
# 247     Western Sahara                     0                               0
# 248              Yemen                     4                               4
# 249             Zambia                    14                              29
# 250           Zimbabwe                     0                               0
#
# ...

# %%
df.replace(',','', regex=True, inplace=True) 
df
# Out:
#                Country Preservation Requests Preservation Accounts Preserved  \
# 0          Afghanistan                     0                               0
# 1        Aland Islands                     0                               0
# 2              Albania                     9                               9
# 3              Algeria                     1                               1
# 4       American Samoa                     0                               0
# ..                 ...                   ...                             ...
# 246  Wallis and Futuna                     0                               0
# 247     Western Sahara                     0                               0
# 248              Yemen                     4                               4
# 249             Zambia                    14                              29
# 250           Zimbabwe                     0                               0
#
# ...

# %%
df['Total Requests'] = df['Total Requests'].astype(int)

# %%
df = df.sort_values( by = 'Total Requests' , ascending = False).head(10)
df
# Out:
#             Country Preservation Requests Preservation Accounts Preserved  \
# 237   United States                 82142                          141631
# 99            India                  4132                            9406
# 80          Germany                   404                             631
# 74           France                   198                             254
# 236  United Kingdom                   511                             775
# 30           Brazil                  4428                            8737
# 229          Turkey                    12                              18
# 174          Poland                   440                             558
# 106           Italy                  1580                            2441
# 140          Mexico                   691                            1969
#
#      Total Requests Number of Requests Where Some Data Produced  \
# 237           61528                                       54181
# ...

# %%
# saving the new file 
df.to_csv('TotalR20.csv', index=False)
